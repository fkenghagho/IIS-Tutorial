# %% [markdown]
# # Integrated Intelligent Systems: Module 2 - Robot Hardware (Tutorial)
#
# This notebook introduces the fundamental components of robot hardwares and the mathematical design of robot hardware.

# %% [markdown]
# ## Part 1: Concepts and Definitions

# %%
from IPython.display import display, HTML,IFrame
display(IFrame('robot_hardware_quiz.html', width=1000, height=1350))
# Out:
#         <iframe
#             width="1000"
#             height="1350"
#             src="robot_hardware_quiz.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Part 2: Introduction to URDF - Unified Robot Description Format
#
# ## 2.1  Theoretical Background

# %%
from IPython.display import display, HTML,IFrame
display(IFrame('urdf_background.html', width=1000, height=2000))
# Out:
#         <iframe
#             width="1000"
#             height="2000"
#             src="urdf_background.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## 2.1  Hands-on: Build your own robot according to specifications below

# %%
from IPython.display import display, HTML,IFrame
display(IFrame('urdf_handon.html', width=1000, height=2000))
# Out:
#         <iframe
#             width="1000"
#             height="2000"
#             src="urdf_handon.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
