# %% [markdown]
# # Integrated Intelligent Systems: Module 6 - Robot Motion Control (Tutorial)
#
# This notebook introduces the fundamentals of robot motion control and basic practices of it.

# %% [markdown]
# ## Part 1: Concepts and Definitions

# %%
from IPython.display import display, HTML,IFrame
display(IFrame('rmc_quiz.html', width=1000, height=1350))
# Out:
#         <iframe
#             width="1000"
#             height="1350"
#             src="rmc_quiz.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Part 2: PID Motion Control

# %%
from IPython.display import display, HTML,IFrame
display(IFrame('pdi.html', width=1000, height=2650))
# Out:
#         <iframe
#             width="1000"
#             height="2650"
#             src="pdi.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Part 3: Hands-On,  Giskard - Motion Control Framework

# %%
from IPython.display import display, HTML,IFrame
display(IFrame('giskard.html', width=1000, height=1000))
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="giskard.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
